# %% [markdown]
# ## 2. Visualization

# %% [markdown]
# <blockquote> Understanding the consumption and production pattern with the installed capacity </blockquote>

# %% [markdown]
# ### Presenting Consumption, Production and Installed Capacity Data All Year

# %%
import pandas as pd
target_data_0 = pd.read_csv('C:/Users/Michelle Natali/Downloads/Group 4 - Data/predict-energy-behavior-of-prosumers/merged_production_consumption_installed_capacity_and_datetime.csv')

# %%
target_data_0
# Out:
#          Unnamed: 0  county county_name  is_business             datetime  \
# 0                 0       0    HARJUMAA            0  2021-09-01 00:00:00
# 1                 2       0    HARJUMAA            0  2021-09-01 00:00:00
# 2                 4       0    HARJUMAA            0  2021-09-01 00:00:00
# 3                 6       0    HARJUMAA            1  2021-09-01 00:00:00
# 4                 8       0    HARJUMAA            1  2021-09-01 00:00:00
# ...             ...     ...         ...          ...                  ...
# 1005787     2012102      15     VÕRUMAA            0  2023-05-29 23:00:00
# 1005788     2012104      15     VÕRUMAA            0  2023-05-29 23:00:00
# 1005789     2012106      15     VÕRUMAA            1  2023-05-29 23:00:00
# 1005790     2012108      15     VÕRUMAA            1  2023-05-29 23:00:00
# 1005791     2012110      15     VÕRUMAA            1  2023-05-29 23:00:00
#
#          installed_capacity  product_type  data_block_id  production  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Melt the DataFrame to long format
melted_df_0 = pd.melt(target_data_0, id_vars='county_name', value_vars=['production', 'consumption', 'installed_capacity'],
                    var_name='variable', value_name='value')

# Create a line plot
sns.set(style="whitegrid")
plt.figure(figsize=(12, 8))
sns.lineplot(x='county_name', y='value', hue='variable', data=melted_df_0, palette='husl')

# Customize the plot
plt.title('Production, Consumption, and Installed Capacity 2021 - 2023')
plt.xlabel('County Name')
plt.ylabel('Megawatt')
plt.legend(title='Legend')

# Show the plot
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better visibility
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Presenting Consumption, Production and Installed Capacity Data All Year

# %% [markdown]
# ### Presenting the Data Yearly

# %% [markdown]
# #### Bar Plot : Consumption, Production and Installed Capacity per Year for each County

# %%
#Separating Data - Yearly
county_year_2021 = target_data_0.loc[(target_data_0['datetime']>='2021-09-01 00:00:00')& 
    (target_data_0['datetime'] <= '2021-12-31 23:00:00')]
county_year_2021
# Out:
#         Unnamed: 0  county county_name  is_business             datetime  \
# 0                0       0    HARJUMAA            0  2021-09-01 00:00:00
# 1                2       0    HARJUMAA            0  2021-09-01 00:00:00
# 2                4       0    HARJUMAA            0  2021-09-01 00:00:00
# 3                6       0    HARJUMAA            1  2021-09-01 00:00:00
# 4                8       0    HARJUMAA            1  2021-09-01 00:00:00
# ...            ...     ...         ...          ...                  ...
# 182956      366038      15     VÕRUMAA            0  2021-12-31 23:00:00
# 182957      366040      15     VÕRUMAA            0  2021-12-31 23:00:00
# 182958      366042      15     VÕRUMAA            1  2021-12-31 23:00:00
# 182959      366044      15     VÕRUMAA            1  2021-12-31 23:00:00
# 182960      366046      15     VÕRUMAA            1  2021-12-31 23:00:00
#
#         installed_capacity  product_type  data_block_id  production  \
# ...

# %%
#Using Mean Data
mean_production_per_county_2021 = county_year_2021.groupby('county_name')['production'].mean().reset_index()
mean_production_per_county_2021
mean_consumption_per_county_2021 = county_year_2021.groupby('county_name')['consumption'].mean().reset_index()
mean_consumption_per_county_2021
mean_installed_capacity_per_county_2021 = county_year_2021.groupby('county_name')['installed_capacity'].mean().reset_index()
mean_installed_capacity_per_county_2021

mean_per_county = county_year_2021.groupby('county_name')[['production','consumption','installed_capacity']].mean().reset_index()
mean_per_county
# Out:
#       county_name  production  consumption  installed_capacity
# 0        HARJUMAA   64.753442  1445.940683         3609.525868
# 1         HIIUMAA   11.851131    33.179529          287.798850
# 2     IDA-VIRUMAA   10.480086   155.327371          386.423682
# 3        JÄRVAMAA   18.293851   279.776877          870.341801
# 4       JÕGEVAMAA   17.279308   213.569333          655.049103
# 5   LÄÄNE-VIRUMAA   20.099341   427.022147         1043.359761
# 6        LÄÄNEMAA    2.483706   126.252475          324.200000
# 7        PÄRNUMAA   25.272181   261.951337         1042.528614
# 8        PÕLVAMAA   16.409366    88.773657          537.380738
# 9        RAPLAMAA   16.754569   105.848464          570.345345
# 10       SAAREMAA   31.605349   327.564725          912.553058
# 11       TARTUMAA   41.799525   894.069185         1797.212224
# 12        UNKNOWN    1.450876   616.980071          241.500000
# 13       VALGAMAA   20.280946   248.288614          518.331498
# ...

# %%
# Plotting Data Per Year - Seaborn Line Plot
# 2021

import seaborn as sns
import matplotlib.pyplot as plt

# Melt the DataFrame to long format
melted_df = pd.melt(mean_per_county, id_vars='county_name', value_vars=['production', 'consumption', 'installed_capacity'],
                    var_name='variable', value_name='value')

# Set the Seaborn style
sns.set_theme(style="whitegrid")

#Create a Bar Chart
plt.figure(figsize=(12, 6))
sns.barplot(x='county_name', y='value', hue='variable', data=melted_df, palette='husl')

# Customize the plot
plt.title('Production, Consumption, and Installed Capacity Year 2021')
plt.xlabel('County Name')
plt.xticks(rotation=45, ha='right')
plt.ylabel('Values')
plt.legend(title='Legend')

# Show the plot
plt.tight_layout()
plt.show()

# %%
#Year 2022
county_year_2022 = target_data_0.loc[(target_data_0['datetime']>='2022-01-01 00:00:00')& 
    (target_data_0['datetime'] <= '2022-12-31 23:00:00')]
county_year_2022

#Convert Datetime
county_year_2022['datetime'] = county_year_2022['datetime'].values.astype('datetime64[h]')
county_year_2022

#Using Mean Data
mean_production_per_county_2022 = county_year_2022.groupby('county_name')['production'].mean().reset_index()
mean_production_per_county_2022
mean_consumption_per_county_2022 = county_year_2022.groupby('county_name')['consumption'].mean().reset_index()
mean_consumption_per_county_2022
mean_installed_capacity_per_county_2022 = county_year_2022.groupby('county_name')['installed_capacity'].mean().reset_index()
mean_installed_capacity_per_county_2022

mean_per_county22 = county_year_2022.groupby('county_name')[['production','consumption','installed_capacity']].mean().reset_index()
mean_per_county22

# Plotting Data Per Year - Seaborn Line plot
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# Melt the DataFrame to long format
melted_df22 = pd.melt(mean_per_county22, id_vars='county_name', value_vars=['production', 'consumption', 'installed_capacity'],
                    var_name='variable', value_name='value')

# Set the Seaborn style
sns.set_theme(style="whitegrid")

#Create a Bar Chart
plt.figure(figsize=(12, 6))
sns.barplot(x='county_name', y='value', hue='variable', data=melted_df22, palette='husl')

# Customize the plot
plt.title('Production, Consumption, and Installed Capacity Year 2022')
plt.xlabel('County Name')
plt.xticks(rotation=45, ha='right')
plt.ylabel('Values')
plt.legend(title='Legend')

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Michelle Natali\AppData\Local\Temp\ipykernel_21292\1102775959.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   county_year_2022['datetime'] = county_year_2022['datetime'].values.astype('datetime64[h]')

# %%
#Year 2023
county_year_2023 = target_data_0.loc[(target_data_0['datetime']>='2023-01-01 00:00:00')& 
    (target_data_0['datetime'] <= '2023-05-29 23:00:00')]
county_year_2023

#Convert Datetime
county_year_2023['datetime'] = county_year_2023['datetime'].values.astype('datetime64[h]')
county_year_2023

#Using Mean Data
mean_production_per_county_2023 = county_year_2023.groupby('county_name')['production'].mean().reset_index()
mean_production_per_county_2023
mean_consumption_per_county_2023 = county_year_2023.groupby('county_name')['consumption'].mean().reset_index()
mean_consumption_per_county_2023
mean_installed_capacity_per_county_2023 = county_year_2023.groupby('county_name')['installed_capacity'].mean().reset_index()
mean_installed_capacity_per_county_2023

mean_per_county23 = county_year_2023.groupby('county_name')[['production','consumption','installed_capacity']].mean().reset_index()
mean_per_county23

# Plotting Data Per Year - Seaborn Line plot
import seaborn as sns
import matplotlib.pyplot as plt

# Melt the DataFrame to long format
melted_df23 = pd.melt(mean_per_county23, id_vars='county_name', value_vars=['production', 'consumption', 'installed_capacity'],
                    var_name='variable', value_name='value')

# Set the Seaborn style
sns.set_theme(style="whitegrid")

#Create a Bar Chart
plt.figure(figsize=(12, 6))
sns.barplot(x='county_name', y='value', hue='variable', data=melted_df23, palette='husl')

# Customize the plot
plt.title('Production, Consumption, and Installed Capacity Year 2023')
plt.xlabel('County Name')
plt.xticks(rotation=45, ha='right')
plt.ylabel('Values')
plt.legend(title='Legend')

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Line Plot : Mean Consumption, Production and Installed Capacity per Year

# %%
# Plotting Data Per Year - Seaborn Line Plot 2021
import pandas as pd
import seaborn as sns

#Separating Data - Yearly
county_year_2021 = target_data_0.loc[(target_data_0['datetime']>='2021-09-01 00:00:00')& 
    (target_data_0['datetime'] <= '2021-12-31 23:00:00')]
county_year_2021

#Convert Datetime
county_year_2021 ['datetime'] = county_year_2021['datetime'].values.astype('datetime64[h]')
county_year_2021
# Out:
#         Unnamed: 0  county county_name  is_business            datetime  \
# 0                0       0    HARJUMAA            0 2021-09-01 00:00:00
# 1                2       0    HARJUMAA            0 2021-09-01 00:00:00
# 2                4       0    HARJUMAA            0 2021-09-01 00:00:00
# 3                6       0    HARJUMAA            1 2021-09-01 00:00:00
# 4                8       0    HARJUMAA            1 2021-09-01 00:00:00
# ...            ...     ...         ...          ...                 ...
# 182956      366038      15     VÕRUMAA            0 2021-12-31 23:00:00
# 182957      366040      15     VÕRUMAA            0 2021-12-31 23:00:00
# 182958      366042      15     VÕRUMAA            1 2021-12-31 23:00:00
# 182959      366044      15     VÕRUMAA            1 2021-12-31 23:00:00
# 182960      366046      15     VÕRUMAA            1 2021-12-31 23:00:00
#
#         installed_capacity  product_type  data_block_id  production  \
# ...

# %%
mean_production_per_2021 = county_year_2021.groupby('datetime')['production'].mean().reset_index()
mean_production_per_2021
mean_consumption_per_2021 = county_year_2021.groupby('datetime')['consumption'].mean().reset_index()
mean_consumption_per_2021
mean_installed_capacity_per_2021 = county_year_2021.groupby('datetime')['installed_capacity'].mean().reset_index()
mean_installed_capacity_per_2021

mean_per_2021 = county_year_2021.groupby('datetime')[['production','consumption','installed_capacity']].mean().reset_index()
mean_per_2021
# Out:
#                 datetime  production  consumption  installed_capacity
# 0    2021-09-01 00:00:00    0.071508   325.570623         1158.348525
# 1    2021-09-01 01:00:00    0.194295   315.820951         1158.348525
# 2    2021-09-01 02:00:00    0.030246   315.752328         1158.348525
# 3    2021-09-01 03:00:00    0.024869   311.909574         1158.348525
# 4    2021-09-01 04:00:00    0.040852   317.493836         1158.348525
# ...                  ...         ...          ...                 ...
# 2922 2021-12-31 19:00:00    0.221857   375.245556         1182.721429
# 2923 2021-12-31 20:00:00    0.191794   361.396667         1182.721429
# 2924 2021-12-31 21:00:00    0.200984   349.526111         1182.721429
# 2925 2021-12-31 22:00:00    0.200778   344.785873         1182.721429
# 2926 2021-12-31 23:00:00    0.202937   337.300889         1182.721429
#
# [2927 rows x 4 columns]

# %%
melted_df_2021 = pd.melt(mean_per_2021, id_vars='datetime', value_vars=['production', 'consumption','installed_capacity'],
                    var_name='variable', value_name='value')

# %%
# Create a line plot
sns.set(style="whitegrid")
plt.figure(figsize=(12, 8))
sns.lineplot(x='datetime', y='value', hue='variable', data=melted_df_2021, palette='husl')

# Customize the plot
plt.title('Production, Consumption, and Installed Capacity Year 2021')
plt.xlabel('Date time')
plt.ylabel('Kilowatt')
plt.legend(title='Legend')

# Show the plot
#plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better visibility
plt.tight_layout()
plt.show()

# %%
# Plotting Data Per Year - Seaborn Line Plot 2022
county_year_2022 = target_data_0.loc[(target_data_0['datetime']>='2022-01-01 00:00:00')& 
    (target_data_0['datetime'] <= '2022-12-31 23:00:00')]
county_year_2022

#Convert Datetime
county_year_2022['datetime'] = county_year_2022['datetime'].values.astype('datetime64[h]')
county_year_2022

#Using Mean Data
mean_production_per_2022 = county_year_2022.groupby('datetime')['production'].mean().reset_index()
mean_production_per_2022
mean_consumption_per_2022 = county_year_2022.groupby('datetime')['consumption'].mean().reset_index()
mean_consumption_per_2022
mean_installed_capacity_per_2022 = county_year_2022.groupby('datetime')['installed_capacity'].mean().reset_index()
mean_installed_capacity_per_2022

mean_per_2022 = county_year_2022.groupby('datetime')[['production','consumption','installed_capacity']].mean().reset_index()
mean_per_2022

# Plotting Data Per Year - Seaborn Line plot
import seaborn as sns
import matplotlib.pyplot as plt

# Melt the DataFrame to long format
melted_df22 = pd.melt(mean_per_2022, id_vars='datetime', value_vars=['production', 'consumption', 'installed_capacity'],
                    var_name='variable', value_name='value')

# Set the Seaborn style
sns.set_theme(style="whitegrid")

#Create a Line Chart
plt.figure(figsize=(12, 8))
#sns.lineplot(x='date', y='value', hue='variable', data=melted_df22, palette='husl', errorbar = None)
sns.lineplot(x='datetime', y='value', hue='variable', data=melted_df22, palette='husl')

# Customize the plot
plt.title('Production, Consumption, and Installed Capacity Year 2022')
plt.xlabel('Datetime')
#plt.xticks(rotation=45, ha='right')
plt.ylabel('Kilowatt')
plt.legend(title='Legend')

# Show the plot
#plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better visibility
plt.tight_layout()
plt.show()

# %%
# Plotting Data Per Year - Seaborn Line Plot 2023
county_year_2023 = target_data_0.loc[(target_data_0['datetime']>='2023-01-01 00:00:00')& 
    (target_data_0['datetime'] <= '2023-05-29 23:00:00')]
county_year_2023

#Convert Datetime
county_year_2023['datetime'] = county_year_2023['datetime'].values.astype('datetime64[h]')
county_year_2023

#Using Mean Data
mean_production_per_2023 = county_year_2023.groupby('datetime')['production'].mean().reset_index()
mean_production_per_2023
mean_consumption_per_2023 = county_year_2023.groupby('datetime')['consumption'].mean().reset_index()
mean_consumption_per_2023
mean_installed_capacity_per_2023 = county_year_2023.groupby('datetime')['installed_capacity'].mean().reset_index()
mean_installed_capacity_per_2023

mean_per_2023 = county_year_2023.groupby('datetime')[['production','consumption','installed_capacity']].mean().reset_index()
mean_per_2023

# Plotting Data Per Year - Seaborn Line plot
import seaborn as sns
import matplotlib.pyplot as plt

# Melt the DataFrame to long format
melted_df23 = pd.melt(mean_per_2023, id_vars='datetime', value_vars=['production', 'consumption', 'installed_capacity'],
                    var_name='variable', value_name='value')

# Set the Seaborn style
sns.set_theme(style="whitegrid")

#Create a Line Graph
plt.figure(figsize=(12, 8))
sns.lineplot(x='datetime', y='value', hue='variable', data=melted_df23, palette='husl')

# Customize the plot
plt.title('Production, Consumption, and Installed Capacity Year 2023')
plt.xlabel('Date time')
#plt.xticks(rotation=45, ha='right')
plt.ylabel('Kilowatt')
plt.legend(title='Legend')

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Plotting Data All Year - Seaborn Line Plot 
county_all_year = target_data_0

#Convert Datetime
county_all_year['datetime'] = county_all_year['datetime'].values.astype('datetime64[h]')
county_all_year

#Using Mean Data
mean_production = county_all_year.groupby('datetime')['production'].mean().reset_index()
mean_production
mean_consumption = county_all_year.groupby('datetime')['consumption'].mean().reset_index()
mean_consumption
mean_installed_capacity = county_all_year.groupby('datetime')['installed_capacity'].mean().reset_index()
mean_installed_capacity

mean = county_all_year.groupby('datetime')[['production','consumption','installed_capacity']].mean().reset_index()
mean

# Plotting Data Per Year - Seaborn Line plot
import seaborn as sns
import matplotlib.pyplot as plt

# Melt the DataFrame to long format
melted_df = pd.melt(mean, id_vars='datetime', value_vars=['production', 'consumption', 'installed_capacity'],
                    var_name='variable', value_name='value')

# Set the Seaborn style
sns.set_theme(style="whitegrid")

#Create a Line Graph
plt.figure(figsize=(12, 8))
sns.lineplot(x='datetime', y='value', hue='variable', data=melted_df, palette='husl')

# Customize the plot
plt.title('Production, Consumption, and Installed Capacity All Year')
plt.xlabel('Date time')
#plt.xticks(rotation=45, ha='right')
plt.ylabel('Kilowatt')
plt.legend(title='Legend')

# Show the plot
plt.tight_layout()
plt.show()
